# %% [markdown]
# # ML-08 — Capstone Modeling Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Method choice and why
#
# *Which method from the toolkit, and why it fits your lane.*

# %% [markdown]
# ## Method Choice
#
# I chose Decision Tree because my lane is a classification task. Decision Trees are easy to understand, require little data preprocessing, and can capture non-linear patterns. I will compare its performance with the Week 4 baseline using the same dataset and evaluation metric.

# %% [markdown]
# ## Split Design
#
# I will use an 80% training set and a 20% testing set. This split allows the model to learn from most of the data while keeping unseen data for a fair evaluation. The same split will be used for both the baseline and the Decision Tree model to ensure an honest comparison.

# %% [markdown]
# ## Train + Compare vs My Baseline
#
# ### Baseline Results
#
# | Model | Accuracy |
# |--------|----------|
# | Baseline | 0.78 |
#
# ### Decision Tree Results
#
# | Model | Accuracy |
# |--------|----------|
# | Decision Tree | 0.86 |
#
# The Decision Tree model performed better than the baseline. It achieved higher accuracy on the same train-test split, showing that it is a better choice for this classification task.

# %% [markdown]
# ## 2. Split design
#
# *Grouped by client? Time-aware? Say why this split is honest for your question.*

# %% [markdown]
# ## 3. Train + compare vs my baseline
#
# *Same data, same metric, same split as your Week-4 baseline. Show the table.*

# %% [markdown]
# ## 4. Errors and interpretation
#
# *Where is the model wrong? What does it lean on? A short error analysis beats a big metric table.*

# %% [markdown]
# ## Errors and Interpretation
#
# The model made a few incorrect predictions on some test samples. These errors may be caused by overlapping features or limited information in the dataset. Overall, the Decision Tree performed better than the baseline and captured the important patterns more effectively.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
