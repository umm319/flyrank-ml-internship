# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# from IPython.display import Markdown
#
# Markdown("""
# ### Unit of Analysis + Time Window
#
# - **One row:** One website page for one day.
# - **Time window:** March 2026 (2026-03).
# - **Prediction target:** Click-Through Rate (CTR).
# - **Decision:** Identify pages that need SEO optimization.
# - **Excluded:** Future information (future clicks, impressions, or CTR) to prevent data leakage.
# """)

# %% [markdown]
# from IPython.display import Markdown
#
# Markdown("""
# ### Fields
#
# **Features**
# - Impressions
# - Average Position
# - Device
# - Country
# - Page URL
#
# **Label**
# - CTR (Click-Through Rate)
#
# **Context**
# - Date
# - Search Query
#
# **Excluded**
# - Future CTR
# - Future Clicks
# - Any feature created using the target value (to avoid leakage)
# """)

# %% [markdown]
# from IPython.display import Markdown
#
# Markdown("""
# ### Verification Queries
#
# #### Query 1 – Verify the grain
# SELECT page, date
# FROM search_console_data
# WHERE month='2026-03'
# LIMIT 5;
#
# Result:
# Each row represents one website page for one day.
#
# ---
#
# #### Query 2 – Row count and date range
# SELECT COUNT(*) AS total_rows,
# MIN(date) AS start_date,
# MAX(date) AS end_date
# FROM search_console_data
# WHERE month='2026-03';
#
# Result:
# Shows the total rows and confirms the March 2026 date range.
#
# ---
#
# #### Query 3 – Availability check
# SELECT COUNT(*)
# FROM search_console_data
# WHERE is_available IS TRUE
# AND month='2026-03';
#
# Result:
# Returns the number of available records after filtering.
# """)

# %% [markdown]
# from IPython.display import Markdown
#
# Markdown("""
# ### Data Limitations
#
# - The dataset only contains historical information.
# - It cannot predict sudden ranking changes caused by external events.
# - Some rows may have missing values.
# - Future clicks or CTR cannot be used because they would cause data leakage.
# """)

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
