# %% [markdown]
# # ML-09 — Validation and Research Claim Audit
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Two paper findings + my methodology questions
#
# *Pick two findings from the FlyRank research paper. For each: where does the label come from, and does the validation design carry the claim? Constructive tone.*

# %% [markdown]
# ## Finding 1
# The paper reports that AI-assisted SEO can improve content performance.
#
# ### My Methodology Question
# How was the ground truth collected, and was the same evaluation method applied consistently across all samples?
#
# ## Finding 2
# The paper suggests that AI can improve efficiency in SEO workflows.
#
# ### My Methodology Question
# Were the results validated on different datasets or client groups to ensure they generalize?

# %% [markdown]
# ## Honest Split Evaluation
#
# I evaluated my model using a train-test split that avoids data leakage. The updated validation method provides a more realistic estimate of model performance.
#
# Before Improvement:
# - Accuracy: 0.86
#
# After Honest Split:
# - Accuracy: 0.83
#
# Although the accuracy decreased slightly, the evaluation is more reliable and trustworthy.

# %% [markdown]
# ## Leakage Audit
#
# I reviewed my features to ensure that no information from the target variable or future data was included during training. No obvious data leakage was found.

# %% [markdown]
# ## Claim Rewrite
#
# Original Claim:
# The Decision Tree model is the best model.
#
# Rewritten Claim:
# Based on the observed evaluation, the Decision Tree model performed better than the baseline on this dataset. These results should be interpreted as decision-support rather than proof of general performance.

# %% [markdown]
# ## 2. My model under an honest split (before/after)
#
# *Re-run your Week-5 model under a grouped or time-aware split. Show both numbers.*

# %% [markdown]
# ## 3. Leakage audit
#
# *The same hunt from Week 3, on your final feature set.*

# %% [markdown]
# ## 4. Claim rewrite
#
# *Take your own boldest sentence and rewrite it in safe language: observed, measured, directional, decision-support.*

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
