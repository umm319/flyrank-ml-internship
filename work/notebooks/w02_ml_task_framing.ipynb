# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ### My Lane as an ML Task
#
# My lane is Machine Learning / Data Science.
#
# Task Type: Classification
#
# The goal is to classify whether content is likely to perform well or not. The model predicts one of two classes: high-performing content or low-performing content.

# %% [markdown]
# ### Target or Proxy
#
# The target is whether a piece of content performs well.
#
# Target:
# - 1 = High-performing content
# - 0 = Low-performing content
#
# The labels come from observed engagement such as clicks, views, or interactions. If real labels are not available, engagement can be used as a proxy.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# ### My Lane as an ML Task
#
# My lane is Machine Learning / Data Science.
#
# Task Type: Classification
#
# The goal is to classify whether content is likely to perform well or not. The model predicts one of two classes: high-performing content or low-performing content.

# %% [markdown]
# ### Target or Proxy
#
# The target is whether a piece of content performs well.
#
# Target:
# - 1 = High-performing content
# - 0 = Low-performing content
#
# The labels come from observed engagement such as clicks, views, or interactions. If real labels are not available, engagement can be used as a proxy.

# %% [markdown]
# ### Success Metric
#
# The main success metric is Accuracy because it measures how often the model predicts the correct class.
#
# A model with an accuracy of 80% or higher would be considered a good starting point. If the dataset is imbalanced, the F1 Score can also be used because it balances precision and recall.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# ### Success Metric
#
# The main success metric is Accuracy because it measures how often the model predicts the correct class.
#
# A model with an accuracy of 80% or higher would be considered a good starting point. If the dataset is imbalanced, the F1 Score can also be used because it balances precision and recall.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
from pathlib import Path

list(Path("data/raw").glob("*"))
# Out:
# []

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# ### Why ML Beats a Fixed Rule
#
# Machine learning is better than a fixed rule because content performance depends on many factors such as topic, keywords, audience behavior, and engagement. A simple if-else rule cannot capture these complex patterns, while an ML model can learn from historical data and make better predictions to support content decisions.

# %%
import pandas as pd
from pathlib import Path

data_path = Path("data/raw")

print("Files:")
for f in data_path.glob("*"):
    print(f.name)
# Out:
# Files:

# %% [markdown]
# ### Why ML Beats a Fixed Rule
#
# Machine learning is better than a fixed rule because content performance depends on many factors such as topic, keywords, audience behavior, and engagement. A simple if-else rule cannot capture these complex patterns, while an ML model can learn from historical data and make better predictions to support content decisions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
